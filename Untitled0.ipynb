# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcoOG69/Outliers/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#instalamos libreria
# %pip install funpymodeling

# %%
#importamos librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#cargar archivo
from google.colab import files
files.upload()

# %%
#carga de un archivo sin indice
MR=pd.read_excel('microretailer_mit_lift_lab.xlsx')

# %%
#verificamos la informacion
MR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Columns: 106 entries, _record_id to 235_email
# dtypes: float64(23), int64(2), object(81)
# memory usage: 141.7+ KB

# %%
#Obtenemos tabla de frecuencias
freq_tbl(MR)

# %%
#Analisis univariado de una variable categórica en especifico
table1=freq_tbl(MR['214_customer_relationship_tools'])
table1

# %%
#obtengo filtro de valores relevantes
filtro=table1[table1['frequency']>1]
filtro

# %%
#Ajusto el indice de mi fataframe
Filtro_index = filtro.set_index('214_customer_relationship_tools')
Filtro_index

# %%
#realizamos grafico de barras
Filtro_index.plot(kind='bar',width=1, figsize=(10,4))
plt.title('Herramientas de relacion con los clientes')
plt.xlabel('Tipo de herramienta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#grafica de dispersion
Filtro_index.plot("frequency","cumulative_perc",kind="scatter")

# %%
#Grafico de area
Filtro_index.plot(kind="area",figsize=(10,4),alpha=1)

# %%
#grafico de pastel
Filtro_index["frequency"].plot(kind='pie',figsize=(10,5),shadow=True,autopct="%0.1f%%")

# %%
#realizamos grafico hexagonal
Filtro_index.plot.hexbin("frequency","cumulative_perc",figsize=(10,5))
